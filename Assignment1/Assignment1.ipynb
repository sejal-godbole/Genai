# %% [markdown]
# <a href="https://colab.research.google.com/github/sejal-godbole/Genai/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Text Generation

# %%
from google import genai

# %%
import google.generativeai as genai
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
genai.configure(api_key="AIzaSyDBjrw6wiipXDJdN6YTGj_dQWu3jy5Qkcc")

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

# %%
response = model.generate_content(
    "Explain probabilistic generative models in simple words."
)

print(response.text)
# Out:
# Imagine you want a computer to draw pictures of cats.
#
# 1.  **Generative Part:** Most AI models are like a "cat detector." They look at a picture and say, "Yep, that's a cat," or "Nope, that's a dog." A *generative* model is different. It's like an artist who's seen thousands of cat pictures and can now *draw a new cat* that's never existed before. Its goal isn't just to recognize, but to *create* something new that looks like the real thing.
#
# 2.  **Probabilistic Part:** When our artist draws a new cat, it won't be exactly the same cat every time. Sometimes it will draw an orange cat, sometimes a fluffy grey cat, sometimes a sleek black cat. It understands that "cats" aren't just one perfect image, but a *variety* of images.
#
#     *   It knows that ears are *usually* pointed (high probability).
#     *   Whiskers are *almost always* present (very high probability).
#     *   Fur color can be *many different things* (more varied probability).
#
# ...

# %% [markdown]
# Image Description

# %%
pip install google-generativeai pillow

# %%
import google.generativeai as genai
from PIL import Image
import base64
import io

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

# %%
response = model.generate_content(
    "A realistic illustration of an EV charging station in an Indian city at night"
)

for part in response.parts:
    if part.inline_data:
        image_bytes = base64.b64decode(part.inline_data.data)
        image = Image.open(io.BytesIO(image_bytes))
        image.save("generated_image.png")
        image.show()

# %%
import PIL.Image

sample_file = PIL.Image.open('cup.jpg')

# %%
img_resized = sample_file.resize((400, 300))
img_resized
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>

# %%
model = genai.GenerativeModel(model_name="gemini-2.5-flash")

prompt = "What can you tell me about this picture?"
response = model.generate_content([prompt, sample_file])

print(response.text)
# Out:
# This picture features a simple, yet inviting scene of a **white ceramic coffee cup** placed on a **rustic wooden surface**.
#
# Here's a breakdown of what can be observed:
#
# *   **Subject:** The central focus is a clean, classic-shaped white coffee or tea cup with a handle visible on the right side. It appears to be made of ceramic or porcelain.
# *   **Contents:** The cup contains a dark brown liquid, suggesting it's coffee, tea, or a similar hot beverage. The liquid level is a little below the rim.
# *   **Setting:** The cup rests on a surface made of natural wood planks. The wood has a distinct grain and texture, showing some signs of age or weathering, with variations in color from light tan to darker brown and greyish undertones. There are visible seams between the individual planks, which run horizontally across the frame.
# ...
